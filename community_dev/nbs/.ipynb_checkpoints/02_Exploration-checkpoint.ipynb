# %%
import pandas as pd

# %%
df = pd.read_csv("../20230507_Messages.csv")
df.head()
# Out:
#               Datetime                                            Message
# 0  2023-03-01 14:28:12  Please leave a one line intro when you join an...
# 1  2023-03-01 14:29:23  I'm Pranjal Mehta. Cofounded ePlane.ai (electr...
# 2  2023-03-01 14:29:25                                        Hey folks,
# 3  2023-03-01 14:29:49  I'm Nirant K. ML/LLM Consultant out of BLR. Mo...
# 4  2023-03-01 14:30:26                                                Hey

# %%
df["Message"][21]
# Out:
# 'Looks like @[PHONE REMOVED] got a DM from our benevolent dictator 😂, welcome to the group'

# %%
# Group by week
df["Datetime"] = pd.to_datetime(df["Datetime"])
df['Week'] = df['Datetime'].dt.isocalendar().week
df['Date'] = df['Datetime'].dt.date

# Group by Date
daily_df = df.groupby('Date').agg({'Message': ' \n '.join}).reset_index()
daily_df = pd.DataFrame(daily_df)
len(daily_df)

# # Group by Week
# weekly_df = df.groupby('Week').agg({'Message': ' \n '.join}).reset_index()
# weekly_df = pd.DataFrame(messages_df)
# print(weekly)
# print(weekly_df["Message"][9])
# Out:
# 66

# %%
daily_df["wc"] = daily_df["Message"].apply(lambda x: len(x.split()))

# %%
daily_df["wc"].describe()
# Out:
# count      66.000000
# mean      906.863636
# std       726.574765
# min         9.000000
# 25%       283.000000
# 50%       701.000000
# 75%      1473.000000
# max      2556.000000
# Name: wc, dtype: float64

# %%
from datetime import date

d = daily_df["Date"][42]

def ordinal(n):
    return "%d%s" % (n, "tsnrhtdd"[((n//10%10!=1)*(n%10<4)*n%10)::4])

formatted_date = d.strftime(f"{ordinal(d.day)} %B %Y")
print(formatted_date)
# Out:
# 14th April 2023

# %%
# Out:
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# ...
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')
# Index(['Datetime', 'Message', 'Week', 'Date'], dtype='object')

# %% [markdown]
# ## Summarization
# Built with Langchain

# %%
from langchain import OpenAI, PromptTemplate, LLMChain
from langchain.chat_models import ChatOpenAI
from langchain.text_splitter import CharacterTextSplitter
from langchain.chains.mapreduce import MapReduceChain
from langchain.prompts import PromptTemplate
from langchain.docstore.document import Document
from langchain.chains.summarize import load_summarize_chain

from functools import lru_cache
llm = ChatOpenAI(temperature=0)

# %%
text_splitter = CharacterTextSplitter.from_tiktoken_encoder()

# %%
# %%time
class SummarizeDay:
    def __init__(self, plain_text):
        self.prompt_template = """This is a chaotic Generative AI Group Chat transcript. Write detailed, exhaustive bullet point recap of topics discussed. Extract COMPLETE URL of web and social links with context. Please organise it into sections, only when needed:

{text}


Use Markdown. Add ## for section titles. TOPICS RECAP:"""
# Research with weblinks where relevant EXACTLY ONCE:
        self.PROMPT = PromptTemplate(template=self.prompt_template, input_variables=["text"])
#         self.chain = load_summarize_chain(ChatOpenAI(temperature=0), chain_type="map_reduce", return_intermediate_steps=True, map_prompt=PROMPT, combine_prompt=PROMPT)
        self.chain = load_summarize_chain(ChatOpenAI(temperature=0), chain_type="stuff", prompt=self.PROMPT)
        self.docs = self.make_docs(plain_text)
        
    @lru_cache
    def make_docs(self, plain_text: str):
        texts = text_splitter.split_text(plain_text)
        docs = [Document(page_content=t) for t in texts]
        return docs

    def summarize_docs(self):   
        chain_output = self.chain({"input_documents": self.docs}, return_only_outputs=True)
        return chain_output
    
    
def summarize(message: str)->str:
    sd = SummarizeDay(message)
    chain_output = sd.summarize_docs()
    summary_text = chain_output["output_text"]
    print(summary_text)
    return summary_text
# Out:
# CPU times: user 39 µs, sys: 48 µs, total: 87 µs
# Wall time: 46 µs

# %%
# %%time
daily_df["Summary"] = daily_df["Message"].apply(summarize)
# Out:
# ## Introductions
# - Members introduced themselves and their backgrounds in AI, ML, and related fields.
#
# ## Projects and Startups
# - Pranjal Mehta cofounded ePlane.ai, an electric plane startup, and is currently interested in building in GenAI.
# - Nirant K is an ML/LLM consultant who works with startups building in ML.
# - Kush is running Corp Dev for Glance & InMobi and is interested in seeing Generative AI innovations in the market.
# - Pranav works in the product team at Pepper Content and leads Peppertype.ai, which closely works with Gen AI and its applications in content and marketing.
# - Sachin is the founder of IntelLawyer.com, a search engine of case laws, and has previously worked as an RL engineer.
# - Amogh is tinkering on a project in generative AI called Youstick.fun, which lets users use their photos to create fun stickers that they can use in Whatsapp, Instagram, Slack, and Discord.
# - Rahul Sundar is a PhD student interested in teaching the science of any underlying problem to machines.
# - Parth is a VC at Venture Highway who looks closely at the Applied AI space and works with a few portfolio companies in the space.
# - Anagh from Accel has been working on AI investments for 3ish years and used to build ML models in the pre-transformers era.
# - Naman from Stellaris VP looks at AI and SaaS investments.
# - Shashwat is working on an AI-based learning and development tool and is primarily interested in recommendation systems and building one for generative media consumption.
#
# ## Topics Discussed
# ### Generative AI
# - Members discussed their interest in generative AI and its applications in various fields, including content and marketing, learning and development, and autonomous driving.
# - Siddharth's thesis was on GANs in voice generation, and he has kept up with the literature and built out some models since.
# - Abhishek Maiti spends an unhealthy amount of time with computer vision and 3D reconstruction and is looking for ways to make the creation of 3D and 2D creative assets as seamless and accurate as possible.
# - Shashwat is building a recommendation system for generative media consumption.
# - Members shared their experiences with building agents to play games and trade stocks.
# - Members discussed the challenges of building and supporting GenAI startups.
#
# ### Tools and Platforms
# - Members shared their experiences with various tools and platforms for generative AI, including RunwayML and Peppertype.ai.
#
# ### Socializing
# - Members engaged in casual conversation, including sharing stickers and joking around.
# ## ChatGPT and Whisper API Update
# - OpenAI shared an update on ChatGPT and Whisper API.
# - They launched the ChatGPT API.
# - A Twitter user shared a tl;dr of the ChatGPT API launch.
# - A member of the group chat shared that they got controlnet working in a way that makes them happy.
#
# ## GPT-3.5-Turbo Deployment
# - Someone asked if anyone has deployed GPT-3.5-Turbo on any of their production apps.
# - They asked about the latencies after a certain scale and if the API is timing out or throwing errors.
# - Another member of the group chat replied that it is mostly stable so far and needs some retries but works with exponential backoff.
#
# ## Corridor Digital's Anime Creation
# - Corridor Digital revealed how they made anime using SD VFX and Blender (scenes).
# - A Twitter user shared the link to the video.
#
# ## Social Links
# - A Twitter user shared a link to Stability AI's Twitter page.
# Generative AI:
#
# - GoogleAI's new Flan-UL2 20B is out
# - Discussion on compute required for good/useful throughput
# - Comparison with chatGPT API in terms of cost and data localization/compliance needs
# - Need for specialized models and configurable/finetunable base models
# - Two interesting articles from a16z on generative AI platform and everyday AI for consumers
# - Links to personal articles on generative AI product strategy and AI products arms race
# - Discussion on fMRI to SD research from Japan and its limitations
# - Personal experience with off-the-shelf brain devices and noise in data
# - Use of fMRI data for cleaner and more interesting analyses
# - Request for resources on using SD for designers and artists
# - Recommendation for Automatic1111 for using SD with plugins, but requires GPU and technical setup
# - Excitement over possibility of getting actual footage of dreams
#
# Miscellaneous:
#
# - YC Founder talks to YC Partner in YouTube video
# ## AI Bot Code
#
# - Hasura AI bot code has been open-sourced
# - It can be easily deployed with one click
# - More information can be found at https://theresanaiforthat.com/
#
# ## AI Art
#
# - Offset Noise is heating up AI Art
# - The original tweet link can be found at https://twitter.com/MetaAI/status/[PHONE REMOVED]?s=20
#
# ## Purchase Parity
#
# - Someone mentioned that Offset Noise's founder is running purchase parity
# - They feel that most products miss this
#
# ## AI Movie
#
# - Someone suggested an AI-themed movie with a twist, similar to Her but with a couple
# ## Introduction
# - Anirudth introduced himself as an Applied Scientist at Amazon
# - He expressed his excitement about generative AI and looking for new opportunities
#
# ## Generative AI
# - Members discussed various applications of generative AI
# - Some mentioned using it for creating art and music
# - Others talked about using it for generating realistic images and videos
# - Members also discussed the potential ethical concerns surrounding generative AI
#
# ## Resources
# - Members shared various resources related to generative AI
# - One member shared a link to a GitHub repository containing various generative AI models (https://github.com/hindupuravinash/the-gan-zoo)
# - Another member shared a link to a blog post about generative AI (https://towardsdatascience.com/generative-models-are-the-future-of-ai-here-s-why-4b0e7e941b33)
#
# ## Tools and Frameworks
# - Members discussed various tools and frameworks for working with generative AI
# - Some mentioned using TensorFlow and PyTorch
# - Others talked about using GANs (Generative Adversarial Networks) and VAEs (Variational Autoencoders)
#
# ## Events and Conferences
# - Members discussed various events and conferences related to generative AI
# - One member mentioned the upcoming NeurIPS conference (https://neurips.cc/)
# - Another member shared a link to the International Conference on Learning Representations (ICLR) (https://iclr.cc/)
#
# ## Social Links
# - No social links were shared in the chat.
# ## Research and Breakthroughs
# - Oxford University researchers introduce a diffusion model called RealFusion that can generate 360-degree reconstructions of objects from an image (https://www.marktechpost.com/2023/02/28/oxford-university-researchers-introduce-a-diffusion-model-called-realfusion-that-can-generate-360-degree-reconstructions-of-objects-from-an-image/?amp)
# - Breakthrough for nerf
#
# ## NeRF and 3D Art
# - Devanshu Tak is a 3D artist who has used NeRF earlier in his work
# - NeRF was used in the Hasura bot for embedding purposes
#
# ## Large Language Models and Embeddings
# - Interesting read: https://unsupervisedlearning.substack.com/p/using-large-language-models-effectively. Esp the #4 point around embeddings
# - Pinecone and Langchain were used in the Hasura bot for embedding purposes
# - OpenAI's embedding endpoint was not used due to cost and latency
# - Chroma bundles store and the embedding call into one from what can be told
#
# ## Prompt Templating
# - Embedding was the biggest reason for using Pinecone and Langchain
# - Langchain gives a good abstraction
# ## Generative AI Hackathon
# - Participants discussing a Generative AI Hackathon
# - No constraint on the problem statement
# - April Fool Apps are welcome
# - Participants asking if everyone has a team
#
# ## Normalizing Flows
# - Participants discussing Normalizing Flows
# - One participant has been interested in it for a while
# - Another participant shows interest
# - Discussion on industrial use cases or academic interest
#
# ## Resource
# - Participants share a resource: https://research.runwayml.com/gen1
# ## Introduction
# - A member of the group shared an opportunity with the group
# - The opportunity is with a large content and consumer brands company in India
# - The company reaches about 40% of all social media users in India
# - The member asked if anyone in the group or anyone they know would be interested in exploring the opportunity
#
# ## No further discussion
#
# There was no further discussion on the opportunity shared by the member.
#
# ## Closing
#
# The group chat ended without any further discussion or topics being brought up.
#
# ## Links
#
# There were no links shared in the group chat.
# ## Introduction
# - Group chat about Generative AI
# - Chaotic conversation
#
# ## Indian Generative AI Landscape
# - Shared link to article about Indian Generative AI Landscape
# - Discussion about the state of AI in India
# - Mention of Indian startups in the AI space
# - Mention of Indian government's AI initiatives
#
# ## GPT-4
# - Shared link to Reddit post about GPT-4
# - Discussion about GPT-4 and its potential capabilities
# - Speculation about the release date of GPT-4
#
# ## Miscellaneous
# - Thanked member for adding to the group chat
# - No other specific topics discussed
# ## Hackathon Registration
# - Participants only need to fill the Google form for the hackathon
# - This chat is for everyone interested in seeing what was built during the hackathon
# - Register for a hackathon invite to the BLR venue: https://forms.gle/UizUwyKi4bajt6WB7
#
# ## GPT Hype
# - Discussion about the hype surrounding GPT
# - Question about whether it is different from the Google form for the hackathon
#
# ## Stable Diffusion
# - Mention of stable diffusion by @[PHONE REMOVED]
# - Joking response about saving face if someone from the company participated
#
# ## Resources
# - Request for anyone with access to Runwayml
# - Link shared to a YouTube video: https://www.youtube.com/watch?v=VdMgPgicvK4
# ## OpenAI LLMs and Foundry
#
# - Discussion about whether there are any LLMs by OpenAI that can be deployed on-premises today
# - Mention of OpenAI Foundry, which costs $1 million per year and will have on-premises capabilities
# - No specific LLMs mentioned that can be deployed on-premises currently
#
# ## FLan-T5 by Google
#
# - Mention of FLan-T5, which is a FOSS (free and open-source software) by Google
#
# ## Thank you
#
# - Thanks given to Nirant for providing quick help
# ## Attendees
# - PMs: @[PHONE REMOVED], @[PHONE REMOVED], @[PHONE REMOVED]
# - Founder and VC: @[PHONE REMOVED], @[PHONE REMOVED]
# - Mumbai based creative agency person: @[PHONE REMOVED]
# - Designer/Data Artist: Rasagy
# - Product Manager: Jay
# - Fintech/Tech Consultant/Trainer: Vikas
# - Lightspeed VC: Manjot
#
# ## Hackathon
# - Prize money split: 1L minimum per track, split between all members of the winning team equally
# - Evaluation criteria: left to jury's discretion, may be shared after demos or made quantitative
# - Some attendees prefer leaving it to the judges, while others prefer having criteria to know what they will be judged on
# - Tracks are announced for the hackathon
#
# ## AI Tools
# - Thoughts on https://alpaca-ai-custom4.ngrok.io/: slow to try prompts, looks more like davinci-002 than the 003 series in terms of ability to follow logic over multiple hops, no weights
# - Instruct dataset is key, PR raised with Huggingface gives training code
# - GPT4 capabilities have a FOSS counterpart from Amazon: github.com/amazon-science/mm-cot
#
# ## Enterprise AI
# - OpenAI's GPT-3 built for enterprise, with enterprise-grade security and scalability
# - 12 cents per 1K token completions is quite expensive
# - Llama-Alpaca experiments may increase due to high cost
# - Be My Eyes demo is hilarious
#
# ## Miscellaneous
# - Attendee asks for help keeping up with technical discussions
# - Attendees introduce themselves and DM each other
# - Attendee asks for details on evaluation criteria for hackathon
# - Attendee expresses dislike for making hackathons like JEE Mains
# - Attendee asks for details on tracks for hackathon
# - Attendee expresses surprise at how much is happening in the AI space in a day
# - Attendee thanks everyone for adding them to the community.
# ## OpenAI Demo and Productivity Apps
# - OpenAI demo of paper wireframe to working code was impressive
# - Discussion on whether this technology would be used more than productivity apps like email, document writing, and slide making
# - Agreement that it may not open up many possibilities for others to build upon, but enough productivity and note apps may become irrelevant
# - Positive feedback on the demos
#
# ## Deep Learning/NLP Research
# - Discussion on resources for deep learning and NLP research, including courses and papers
# - Recommendation to watch Karpathy's nonogpt video
# - Suggestion to work backwards from existing models to study their building blocks
# - Question on whether Xavi Amatriain's catalog is a good read for beginners
# - Acknowledgment that it may be overwhelming for those who are not up-to-date with the latest concepts
# - Non-technical questions are welcome
#
# ## Transformers and Fine-Tuning
# - Discussion on whether transformers will be replaced by a new architecture in the future
# - Opinion that fine-tuning any LLM is tricky
# - Question on whether fine-tuning is needed for most use cases or if prompt engineering is sufficient
# - Suggestion that prompt optimization may be more lucrative due to the larger possible size of prompts
# - Mention of Stable Diffusion for more control, power, and flexibility
# - Recommendation to explore image2image, in-painting, out-painting, and instruct pix2pix
#
# ## Prompt to Art and Image2Image
# - Discussion on the next steps for artists experimenting with prompt to art on Midjourney and Dall-e
# - Mention of Playgroundai and Alex from Carper AI presenting at the W&B conference
# - Recommendation to explore image2image, in-painting, out-painting, and instruct pix2pix
# - Mention of different web UIs for Stable Diffusion in a write-up
#
# ## Empowering Artists
# - Mention of working with artists and their flows to figure out how to empower them more
#
# ## Emergent Properties of Models
# - Question on whether there are any works that show when emergent properties arise during training
# - Mention of research showing that bigger models have more emergent properties
# - Context provided with a Google palm blog post on scaling language models
#
# ## Miscellaneous
# - Request for experts to lend their expertise around StableDiffusion
# - Mention of a tweet about RNNs fighting back
# - Acknowledgment that prompt engineering changes with each new release and the system gets better at understanding what the user is looking for
# - Mention of a LinkedIn post about organizing an activity in Bangalore
# ## Resource Sharing
# - One member shares that they have read all papers related to popular models and suggests it helps to understand the differences.
# - Another member thanks them and expresses interest in exploring the resource as well.
# - A member mentions enjoying the game of trying to get into the mind of research teams and guessing failed experiments.
# - Suggestions are made to play this game in arcade or hard mode, such as comparing interdisciplinary papers or hosting a reading session with multiple people presenting different papers.
# - A resource is shared and appreciated by members.
# - A member asks if there are any paper reading groups happening in Bangalore and if there is a channel to discover them.
# - Suggestions are made for paper reading groups run by Sumod Mohan and Swanand via Hasgeek.
# - A member expresses interest in listening in on a reading group.
#
# ## Event Planning
# - A member suggests spontaneously organizing paper reading groups in Bangalore.
# - A member offers to share the time and venue if they receive more than 5 DMs, and suggests using Zoom if more than 3 of those are non-BLR.
# - Another member expresses interest and sends a DM.
# - A member asks that DMs not be replied to in the group chat to avoid spam.
#
# ## Links Shared
# - A Twitter link is shared: https://twitter.com/LangChainAI/status/[PHONE REMOVED]?t=aUUOXK9kILoYkyVzVgjdhg&s=19
# - A member thanks another for sharing a resource and mentions needing to explore it. No URL is provided.
# ## Performance and Large Scale Searches
# - Discussion about the performance of a tool for large scale searches
# - Mention of specific vector database like Pinecone for better results
# - No performance tests have been done yet
#
# ## Language Models and Dataset
# - Question about why language models have cut off in 2021, including GPT-4
# - Explanation that training involves curating a dataset which is a lot of effort
# - Cleaning and wrangling the data takes a lot of time
# - Some language models use open source datasets
# - GPT-4 paper might have the dataset details
# - Disappointment with the GPT-4 paper
#
# ## ChatGPT-3 Whatsapp Bot
# - Description of a chatbot that can summarise videos, transcribe voice notes, answer text questions, and generate images using /image
# - Interest in using it for productivity
#
# ## Hackathon Sponsorship
# - Announcement that Replit.com will be sponsoring the hackathon
#
# ## LLM Discussion
# - Discussion about the behavior of a language model in relation to data from 2022
# - Confusion about the model's official position on the cutoff date
# - Mention of IFRNet and partial answers
# - Humorous comment about the life of an LLM
# New BingGPT Launch:
# - Potential to make advertising briefs easier
# - Link: https://www.bing.com/new
#
# AI and Software Engineering:
# - Discussion on how GPT4 will change software engineering
# - Link to article: N/A
#
# March Meetup:
# - Question about whether the March meetup for Gen AI is happening
# - No meetup in March, suggestion to come to the hackathon instead
# - RSVP/sign-up link requested
# - Link: N/A
#
# Image Generation Models:
# - Discussion on using image generation models
# - Mention of Midjourney, cvitai, openjourney, protogen, gooey.ai, and illuminati diffusion models
# - Link to cvitai: https://civitai.com/
#
# LORA and Alpaca:
# - Discussion on using LORA and self-instruct datasets to improve Alpaca
# - Offer of sponsorship and contribution of datasets
# - Link to Alpaca self-instruct dataset: https://github.com/tatsu-lab/stanford_alpaca/blob/main/alpaca_data.json
# - Link to Alpaca article: https://crfm.stanford.edu/2023/03/13/alpaca.html
#
# Other Topics:
# - Offset noise write-up: https://www.crosslabs.org/blog/diffusion-with-offset-noise
# - Discussion on Google and Blender ControlNet for posture and depth
# - Mention of facial keypoints for better control in image generation
# - Humorous comments on lack of sleep and use of Adderall
# ## Introduction and Hackathon Demos
# - Confirmed FOSS demos for the hackathon
# - 2 of the top 3 projects from Github Trending in AI
# - Ravi Theja introduced GPT-Index contributor and inMobi DS
# - Nick Floats shared a Twitter link: https://mobile.twitter.com/nickfloats/status/[PHONE REMOVED]
#
# ## Blog and LLMs
# - Shared a favorite blog from the last few weeks: https://simonwillison.net/2023/Mar/17/beat-chatgpt-in-a-browser/
# - WASM for LLMs is super interesting
# - Someone asked if anyone has tried it
# - Came across a link related to the topic
#
# ## LLMs and AI
# - They trained an LLM to mimic Homer Simpson and it's apparently better than GPT-4
# - Someone joked that it would be hilarious if the model forgot how to do chain of thought reasoning because of that
# - Discussion about building a tool like this for VCs
# - Good customers to sell to and solid use case of AI
#
# ## Research Labs
# - Someone suggested reaching out to research labs at IIT Madras or Bombay
# - They might help or redirect to the appropriate organization
# ## AI Models and Tools
# - Hugging Face's ModelScope Text-to-Video Synthesis
# - Reid Hoffmann's essay on GPT4
# - Midjourney for generic imagery and applications like blog post images, moodboards, inspiration images, and stock images
# - InvokeAI's open source UI for Stable Diffusion
# - Automatic1111 as a crazy hacker's option
# - RunwayML Gen1
# - Comfy UI, a node-based/DAG interface for image generation
#
# ## AI Impact and Ethics
# - OpenAI's paper on the potential impact of Large Language Models on the Labor Market
#
# ## AI in Advertising
# - Kishore's product pipeline for generating statics for advertisers
#
# ## Miscellaneous
# - Conspiracy theory about someone spiking SF's water supply with Adderall
# - Replit templates for AI projects
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed exec>:1
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/personal/lib/python3.9/site-packages/pandas/core/series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/personal/lib/python3.9/site-packages/pandas/core/apply.py:1123, in SeriesApply.apply(self)
#    1120     return self.apply_str()
#    1122 # self.f is Callable
# -> 1123 return self.apply_standard()
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/personal/lib/python3.9/site-packages/pandas/core/apply.py:1174, in SeriesApply.apply_standard(self)
#    1172     else:
#    1173         values = obj.astype(object)._values
# -> 1174         mapped = lib.map_infer(
#    1175             values,
#    1176             f,
#    1177             convert=self.convert_dtype,
#    1178         )
#    1180 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1181     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1182     #  See also GH#25959 regarding EA support
#    1183     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/personal/lib/python3.9/site-packages/pandas/_libs/lib.pyx:2924, in pandas._libs.lib.map_infer()
#
# File <timed exec>:28, in summarize(message)
#
# File <timed exec>:22, in summarize_docs(self)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/personal/lib/python3.9/site-packages/langchain/chains/base.py:116, in Chain.__call__(self, inputs, return_only_outputs)
#     114 except (KeyboardInterrupt, Exception) as e:
#     115     self.callback_manager.on_chain_error(e, verbose=self.verbose)
# --> 116     raise e
#     117 self.callback_manager.on_chain_end(outputs, verbose=self.verbose)
#     118 return self.prep_outputs(inputs, outputs, return_only_outputs)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/personal/lib/python3.9/site-packages/langchain/chains/base.py:113, in Chain.__call__(self, inputs, return_only_outputs)
#     107 self.callback_manager.on_chain_start(
#     108     {"name": self.__class__.__name__},
#     109     inputs,
#     110     verbose=self.verbose,
#     111 )
#     112 try:
# --> 113     outputs = self._call(inputs)
#     114 except (KeyboardInterrupt, Exception) as e:
#     115     self.callback_manager.on_chain_error(e, verbose=self.verbose)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/personal/lib/python3.9/site-packages/langchain/chains/combine_documents/base.py:56, in BaseCombineDocumentsChain._call(self, inputs)
#      54 # Other keys are assumed to be needed for LLM prediction
#      55 other_keys = {k: v for k, v in inputs.items() if k != self.input_key}
# ---> 56 output, extra_return_dict = self.combine_docs(docs, **other_keys)
#      57 extra_return_dict[self.output_key] = output
#      58 return extra_return_dict
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/personal/lib/python3.9/site-packages/langchain/chains/combine_documents/stuff.py:89, in StuffDocumentsChain.combine_docs(self, docs, **kwargs)
#      87 inputs = self._get_inputs(docs, **kwargs)
#      88 # Call predict on the LLM.
# ---> 89 return self.llm_chain.predict(**inputs), {}
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/personal/lib/python3.9/site-packages/langchain/chains/llm.py:151, in LLMChain.predict(self, **kwargs)
#     137 def predict(self, **kwargs: Any) -> str:
#     138     """Format prompt with kwargs and pass to LLM.
#     139
#     140     Args:
#    (...)
#     149             completion = llm.predict(adjective="funny")
#     150     """
# --> 151     return self(kwargs)[self.output_key]
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/personal/lib/python3.9/site-packages/langchain/chains/base.py:116, in Chain.__call__(self, inputs, return_only_outputs)
#     114 except (KeyboardInterrupt, Exception) as e:
#     115     self.callback_manager.on_chain_error(e, verbose=self.verbose)
# --> 116     raise e
#     117 self.callback_manager.on_chain_end(outputs, verbose=self.verbose)
#     118 return self.prep_outputs(inputs, outputs, return_only_outputs)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/personal/lib/python3.9/site-packages/langchain/chains/base.py:113, in Chain.__call__(self, inputs, return_only_outputs)
#     107 self.callback_manager.on_chain_start(
#     108     {"name": self.__class__.__name__},
#     109     inputs,
#     110     verbose=self.verbose,
#     111 )
#     112 try:
# --> 113     outputs = self._call(inputs)
#     114 except (KeyboardInterrupt, Exception) as e:
#     115     self.callback_manager.on_chain_error(e, verbose=self.verbose)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/personal/lib/python3.9/site-packages/langchain/chains/llm.py:57, in LLMChain._call(self, inputs)
#      56 def _call(self, inputs: Dict[str, Any]) -> Dict[str, str]:
# ---> 57     return self.apply([inputs])[0]
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/personal/lib/python3.9/site-packages/langchain/chains/llm.py:118, in LLMChain.apply(self, input_list)
#     116 def apply(self, input_list: List[Dict[str, Any]]) -> List[Dict[str, str]]:
#     117     """Utilize the LLM generate method for speed gains."""
# --> 118     response = self.generate(input_list)
#     119     return self.create_outputs(response)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/personal/lib/python3.9/site-packages/langchain/chains/llm.py:62, in LLMChain.generate(self, input_list)
#      60 """Generate LLM result from inputs."""
#      61 prompts, stop = self.prep_prompts(input_list)
# ---> 62 return self.llm.generate_prompt(prompts, stop)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/personal/lib/python3.9/site-packages/langchain/chat_models/base.py:82, in BaseChatModel.generate_prompt(self, prompts, stop)
#      80 except (KeyboardInterrupt, Exception) as e:
#      81     self.callback_manager.on_llm_error(e, verbose=self.verbose)
# ---> 82     raise e
#      83 self.callback_manager.on_llm_end(output, verbose=self.verbose)
#      84 return output
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/personal/lib/python3.9/site-packages/langchain/chat_models/base.py:79, in BaseChatModel.generate_prompt(self, prompts, stop)
#      75 self.callback_manager.on_llm_start(
#      76     {"name": self.__class__.__name__}, prompt_strings, verbose=self.verbose
#      77 )
#      78 try:
# ---> 79     output = self.generate(prompt_messages, stop=stop)
#      80 except (KeyboardInterrupt, Exception) as e:
#      81     self.callback_manager.on_llm_error(e, verbose=self.verbose)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/personal/lib/python3.9/site-packages/langchain/chat_models/base.py:54, in BaseChatModel.generate(self, messages, stop)
#      50 def generate(
#      51     self, messages: List[List[BaseMessage]], stop: Optional[List[str]] = None
#      52 ) -> LLMResult:
#      53     """Top Level call"""
# ---> 54     results = [self._generate(m, stop=stop) for m in messages]
#      55     llm_output = self._combine_llm_outputs([res.llm_output for res in results])
#      56     generations = [res.generations for res in results]
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/personal/lib/python3.9/site-packages/langchain/chat_models/base.py:54, in <listcomp>(.0)
#      50 def generate(
#      51     self, messages: List[List[BaseMessage]], stop: Optional[List[str]] = None
#      52 ) -> LLMResult:
#      53     """Top Level call"""
# ---> 54     results = [self._generate(m, stop=stop) for m in messages]
#      55     llm_output = self._combine_llm_outputs([res.llm_output for res in results])
#      56     generations = [res.generations for res in results]
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/personal/lib/python3.9/site-packages/langchain/chat_models/openai.py:266, in ChatOpenAI._generate(self, messages, stop)
#     262     message = _convert_dict_to_message(
#     263         {"content": inner_completion, "role": role}
#     264     )
#     265     return ChatResult(generations=[ChatGeneration(message=message)])
# --> 266 response = self.completion_with_retry(messages=message_dicts, **params)
#     267 return self._create_chat_result(response)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/personal/lib/python3.9/site-packages/langchain/chat_models/openai.py:228, in ChatOpenAI.completion_with_retry(self, **kwargs)
#     224 @retry_decorator
#     225 def _completion_with_retry(**kwargs: Any) -> Any:
#     226     return self.client.create(**kwargs)
# --> 228 return _completion_with_retry(**kwargs)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/personal/lib/python3.9/site-packages/tenacity/__init__.py:289, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     287 @functools.wraps(f)
#     288 def wrapped_f(*args: t.Any, **kw: t.Any) -> t.Any:
# --> 289     return self(f, *args, **kw)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/personal/lib/python3.9/site-packages/tenacity/__init__.py:379, in Retrying.__call__(self, fn, *args, **kwargs)
#     377 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     378 while True:
# --> 379     do = self.iter(retry_state=retry_state)
#     380     if isinstance(do, DoAttempt):
#     381         try:
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/personal/lib/python3.9/site-packages/tenacity/__init__.py:314, in BaseRetrying.iter(self, retry_state)
#     312 is_explicit_retry = fut.failed and isinstance(fut.exception(), TryAgain)
#     313 if not (is_explicit_retry or self.retry(retry_state)):
# --> 314     return fut.result()
#     316 if self.after is not None:
#     317     self.after(retry_state)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/personal/lib/python3.9/concurrent/futures/_base.py:439, in Future.result(self, timeout)
#     437     raise CancelledError()
#     438 elif self._state == FINISHED:
# --> 439     return self.__get_result()
#     441 self._condition.wait(timeout)
#     443 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/personal/lib/python3.9/concurrent/futures/_base.py:391, in Future.__get_result(self)
#     389 if self._exception:
#     390     try:
# --> 391         raise self._exception
#     392     finally:
#     393         # Break a reference cycle with the exception in self._exception
#     394         self = None
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/personal/lib/python3.9/site-packages/tenacity/__init__.py:382, in Retrying.__call__(self, fn, *args, **kwargs)
#     380 if isinstance(do, DoAttempt):
#     381     try:
# --> 382         result = fn(*args, **kwargs)
#     383     except BaseException:  # noqa: B902
#     384         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/personal/lib/python3.9/site-packages/langchain/chat_models/openai.py:226, in ChatOpenAI.completion_with_retry.<locals>._completion_with_retry(**kwargs)
#     224 @retry_decorator
#     225 def _completion_with_retry(**kwargs: Any) -> Any:
# --> 226     return self.client.create(**kwargs)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/personal/lib/python3.9/site-packages/openai/api_resources/chat_completion.py:25, in ChatCompletion.create(cls, *args, **kwargs)
#      23 while True:
#      24     try:
# ---> 25         return super().create(*args, **kwargs)
#      26     except TryAgain as e:
#      27         if timeout is not None and time.time() > start + timeout:
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/personal/lib/python3.9/site-packages/openai/api_resources/abstract/engine_api_resource.py:153, in EngineAPIResource.create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     127 @classmethod
#     128 def create(
#     129     cls,
#    (...)
#     136     **params,
#     137 ):
#     138     (
#     139         deployment_id,
#     140         engine,
#    (...)
#     150         api_key, api_base, api_type, api_version, organization, **params
#     151     )
# --> 153     response, _, api_key = requestor.request(
#     154         "post",
#     155         url,
#     156         params=params,
#     157         headers=headers,
#     158         stream=stream,
#     159         request_id=request_id,
#     160         request_timeout=request_timeout,
#     161     )
#     163     if stream:
#     164         # must be an iterator
#     165         assert not isinstance(response, OpenAIResponse)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/personal/lib/python3.9/site-packages/openai/api_requestor.py:216, in APIRequestor.request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     205 def request(
#     206     self,
#     207     method,
#    (...)
#     214     request_timeout: Optional[Union[float, Tuple[float, float]]] = None,
#     215 ) -> Tuple[Union[OpenAIResponse, Iterator[OpenAIResponse]], bool, str]:
# --> 216     result = self.request_raw(
#     217         method.lower(),
#     218         url,
#     219         params=params,
#     220         supplied_headers=headers,
#     221         files=files,
#     222         stream=stream,
#     223         request_id=request_id,
#     224         request_timeout=request_timeout,
#     225     )
#     226     resp, got_stream = self._interpret_response(result, stream)
#     227     return resp, got_stream, self.api_key
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/personal/lib/python3.9/site-packages/openai/api_requestor.py:516, in APIRequestor.request_raw(self, method, url, params, supplied_headers, files, stream, request_id, request_timeout)
#     514     _thread_context.session = _make_session()
#     515 try:
# --> 516     result = _thread_context.session.request(
#     517         method,
#     518         abs_url,
#     519         headers=headers,
#     520         data=data,
#     521         files=files,
#     522         stream=stream,
#     523         timeout=request_timeout if request_timeout else TIMEOUT_SECS,
#     524         proxies=_thread_context.session.proxies,
#     525     )
#     526 except requests.exceptions.Timeout as e:
#     527     raise error.Timeout("Request timed out: {}".format(e)) from e
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/personal/lib/python3.9/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/personal/lib/python3.9/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/personal/lib/python3.9/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/personal/lib/python3.9/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/personal/lib/python3.9/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/personal/lib/python3.9/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/personal/lib/python3.9/http/client.py:1377, in HTTPConnection.getresponse(self)
#    1375 try:
#    1376     try:
# -> 1377         response.begin()
#    1378     except ConnectionError:
#    1379         self.close()
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/personal/lib/python3.9/http/client.py:320, in HTTPResponse.begin(self)
#     318 # read until we get a non-100 response
#     319 while True:
# --> 320     version, status, reason = self._read_status()
#     321     if status != CONTINUE:
#     322         break
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/personal/lib/python3.9/http/client.py:281, in HTTPResponse._read_status(self)
#     280 def _read_status(self):
# --> 281     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282     if len(line) > _MAXLINE:
#     283         raise LineTooLong("status line")
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/personal/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/personal/lib/python3.9/ssl.py:1242, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1238     if flags != 0:
#    1239         raise ValueError(
#    1240           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1241           self.__class__)
# -> 1242     return self.read(nbytes, buffer)
#    1243 else:
#    1244     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/personal/lib/python3.9/ssl.py:1100, in SSLSocket.read(self, len, buffer)
#    1098 try:
#    1099     if buffer is not None:
# -> 1100         return self._sslobj.read(len, buffer)
#    1101     else:
#    1102         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import re
WINDOW = 1
def extract_urls_with_context(text):
    lines = text.split('\n')
    url_pattern = re.compile(r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')
    urls_with_context = []

    for idx, line in enumerate(lines):
        for match in url_pattern.finditer(line):
            start, end = match.span()
            prev_line = lines[idx - WINDOW] if idx > 0 else ""
            next_line = lines[idx + WINDOW] if idx < len(lines) - 1 else ""
            context = f"{prev_line}\n{line}\n{next_line}".strip()
            urls_with_context.append((match.group(), context))

    return urls_with_context


    urls_with_context = extract_urls_with_context(url)
    for url, context in urls_with_context:
        print(f"URL: {url}")
        print(f"Context: {context}\n")
        


class LinksContext:
    def __init__(self, plain_text):
        self.prompt_template = """For each URL, there is some context. Newlines may or may not be related to the link, but the message in the same link as link is related to the link.
        
{text}
        
Mention URL with context. Single bullet point:"""
# Research with weblinks where relevant EXACTLY ONCE:
        self.PROMPT = PromptTemplate(template=self.prompt_template, input_variables=["text"])
#         self.chain = load_summarize_chain(ChatOpenAI(temperature=0, model_name="gpt-4"), chain_type="map_reduce", return_intermediate_steps=True, map_prompt=PROMPT, combine_prompt=PROMPT)
        self.chain = load_summarize_chain(ChatOpenAI(temperature=0), chain_type="stuff", prompt=self.PROMPT)
        self.docs = self.make_docs(plain_text)
        
    @lru_cache
    def make_docs(self, plain_text: str):
        texts = text_splitter.split_text(plain_text)
        docs = [Document(page_content=t) for t in texts]
        return docs

    def summarize_docs(self):   
        chain_output = self.chain({"input_documents": self.docs}, return_only_outputs=True)
        return chain_output

plain_text = daily_df["Message"][54]
url_groups = extract_urls_with_context(plain_text)
for ug in url_groups:
    lc = LinksContext(ug[1])
    chain_output = lc.summarize_docs()
    output_text = chain_output["output_text"]
    print(output_text)
